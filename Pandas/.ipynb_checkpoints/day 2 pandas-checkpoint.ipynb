# %%
import pandas as pd

# %%
df=pd.read_excel(r"C:\Users\anshu\OneDrive\Documents\Excel files\Data of Smartphones.xlsx")
df
# Out:
#        Unnamed: 0                                         Model Name    Price  \
# 0               0                vivo T4x 5G (Pronto Purple, 256 GB)  18499.0
# 1               1    MOTOROLA G96 5G (Pantone Ashleigh Blue, 256 GB)  18999.0
# 2               2                vivo T4x 5G (Pronto Purple, 128 GB)  16499.0
# 3               3  MOTOROLA G96 5G (Pantone Greener Pastures, 256...  18999.0
# 4               4                 realme P4x 5G (Lake Green, 256 GB)  17499.0
# ...           ...                                                ...      ...
# 11971       11971                   OPPO A6x 5G (Olive Green, 64 GB)  12499.0
# 11972       11972                  OPPO A6x 5G (Olive Green, 128 GB)  13499.0
# 11973       11973  realme C63 5G Charger in the Box (Forest Green...  10999.0
# 11974       11974           vivo Y19s 5G (Titanium Silver, 128.0 GB)  14499.0
# 11975       11975                  realme C73 5G (Onyx Black, 64 GB)  11999.0
#
# ...

# %%
df.shape
# Out:
# (11976, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11976 entries, 0 to 11975
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           11976 non-null  int64
#  1   Model Name           11976 non-null  object
#  2   Price                11966 non-null  float64
#  3   Percentage Discount  11856 non-null  object
#  4   Ratings              11957 non-null  float64
#  5   Reviews              11957 non-null  float64
#  6   RAM & ROM            11976 non-null  object
#  7   Display Size         11976 non-null  object
#  8   Camera               11976 non-null  object
#  9   Battery Capacity     11975 non-null  object
#  10  Processor            11966 non-null  object
#  11  Warranty             11734 non-null  object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 1.1+ MB

# %%
k=[2]*11976 
df['Tax']=k
df
# Out:
#        Unnamed: 0                                         Model Name    Price  \
# 0               0                vivo T4x 5G (Pronto Purple, 256 GB)  18499.0
# 1               1    MOTOROLA G96 5G (Pantone Ashleigh Blue, 256 GB)  18999.0
# 2               2                vivo T4x 5G (Pronto Purple, 128 GB)  16499.0
# 3               3  MOTOROLA G96 5G (Pantone Greener Pastures, 256...  18999.0
# 4               4                 realme P4x 5G (Lake Green, 256 GB)  17499.0
# ...           ...                                                ...      ...
# 11971       11971                   OPPO A6x 5G (Olive Green, 64 GB)  12499.0
# 11972       11972                  OPPO A6x 5G (Olive Green, 128 GB)  13499.0
# 11973       11973  realme C63 5G Charger in the Box (Forest Green...  10999.0
# 11974       11974           vivo Y19s 5G (Titanium Silver, 128.0 GB)  14499.0
# 11975       11975                  realme C73 5G (Onyx Black, 64 GB)  11999.0
#
# ...

# %%
k2=['Made in india']*11976 
df.insert(3,'Manufacture',k2)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13448\2399958937.py in ?()
#       1 k2=['Made in india']*11976
# ----> 2 df.insert(3,'Manufacture',k2)
#       3 df
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
#    5176                 "'self.flags.allows_duplicate_labels' is False."
#    5177             )
#    5178         if not allow_duplicates and column in self.columns:
#    5179             # Should this be a different kind of error??
# -> 5180             raise ValueError(f"cannot insert {column}, already exists")
#    5181         if not is_integer(loc):
#    5182             raise TypeError("loc must be int")
#    5183         # convert non stdlib ints to satisfy typing checks
#
# ValueError: cannot insert Manufacture, already exists

# %%
df.drop(['Country'],axis=1,inplace=True)

# %%
df
# Out:
#        Unnamed: 0                                         Model Name    Price  \
# 0               0                vivo T4x 5G (Pronto Purple, 256 GB)  18499.0
# 1               1    MOTOROLA G96 5G (Pantone Ashleigh Blue, 256 GB)  18999.0
# 2               2                vivo T4x 5G (Pronto Purple, 128 GB)  16499.0
# 3               3  MOTOROLA G96 5G (Pantone Greener Pastures, 256...  18999.0
# 4               4                 realme P4x 5G (Lake Green, 256 GB)  17499.0
# ...           ...                                                ...      ...
# 11971       11971                   OPPO A6x 5G (Olive Green, 64 GB)  12499.0
# 11972       11972                  OPPO A6x 5G (Olive Green, 128 GB)  13499.0
# 11973       11973  realme C63 5G Charger in the Box (Forest Green...  10999.0
# 11974       11974           vivo Y19s 5G (Titanium Silver, 128.0 GB)  14499.0
# 11975       11975                  realme C73 5G (Onyx Black, 64 GB)  11999.0
#
# ...

# %%
df['Rank']=df['Price'].rank().fillna(0).astype(int)
df
# Out:
#        Unnamed: 0                                         Model Name    Price  \
# 0               0                vivo T4x 5G (Pronto Purple, 256 GB)  18499.0
# 1               1    MOTOROLA G96 5G (Pantone Ashleigh Blue, 256 GB)  18999.0
# 2               2                vivo T4x 5G (Pronto Purple, 128 GB)  16499.0
# 3               3  MOTOROLA G96 5G (Pantone Greener Pastures, 256...  18999.0
# 4               4                 realme P4x 5G (Lake Green, 256 GB)  17499.0
# ...           ...                                                ...      ...
# 11971       11971                   OPPO A6x 5G (Olive Green, 64 GB)  12499.0
# 11972       11972                  OPPO A6x 5G (Olive Green, 128 GB)  13499.0
# 11973       11973  realme C63 5G Charger in the Box (Forest Green...  10999.0
# 11974       11974           vivo Y19s 5G (Titanium Silver, 128.0 GB)  14499.0
# 11975       11975                  realme C73 5G (Onyx Black, 64 GB)  11999.0
#
# ...

# %%
df['Rank']=df['Price'].rank(ascending=False).fillna(0).astype(int)
df
# Out:
#        Unnamed: 0                                         Model Name    Price  \
# 0               0                vivo T4x 5G (Pronto Purple, 256 GB)  18499.0
# 1               1    MOTOROLA G96 5G (Pantone Ashleigh Blue, 256 GB)  18999.0
# 2               2                vivo T4x 5G (Pronto Purple, 128 GB)  16499.0
# 3               3  MOTOROLA G96 5G (Pantone Greener Pastures, 256...  18999.0
# 4               4                 realme P4x 5G (Lake Green, 256 GB)  17499.0
# ...           ...                                                ...      ...
# 11971       11971                   OPPO A6x 5G (Olive Green, 64 GB)  12499.0
# 11972       11972                  OPPO A6x 5G (Olive Green, 128 GB)  13499.0
# 11973       11973  realme C63 5G Charger in the Box (Forest Green...  10999.0
# 11974       11974           vivo Y19s 5G (Titanium Silver, 128.0 GB)  14499.0
# 11975       11975                  realme C73 5G (Onyx Black, 64 GB)  11999.0
#
# ...

# %%
df.sort_values(['Rank'])
# Out:
#      Unnamed: 0                                         Model Name  Price  \
# 365         365                                       OPPO K12X 5G    NaN
# 321         321                   vivo T1 44W (Starry Sky, 128 GB)    NaN
# 334         334                                         I Kall K25    NaN
# 528         528     I Kall K555 TOUCH AND TYPE Phone (Blue, 16 GB)    NaN
# 431         431                                         I Kall K25    NaN
# ..          ...                                                ...    ...
# 335         335                                       TRYTO T1 106  680.0
# 434         434  Vox V17 New - Keypad Mobile Phone with 1.8" di...  655.0
# 573         573  IAIR Basic Feature Dual Sim Mobile Phone with ...  610.0
# 491         491                                           Peace P6  599.0
# 529         529                                           Peace P2  598.0
#
#        Manufacture Percentage Discount   Ratings  Reviews  \
# ...

# %%
df['Densrank']=df['Price'].rank(method='dense',ascending=False).fillna(0).astype(int)
df
# Out:
#        Unnamed: 0                                         Model Name    Price  \
# 0               0                vivo T4x 5G (Pronto Purple, 256 GB)  18499.0
# 1               1    MOTOROLA G96 5G (Pantone Ashleigh Blue, 256 GB)  18999.0
# 2               2                vivo T4x 5G (Pronto Purple, 128 GB)  16499.0
# 3               3  MOTOROLA G96 5G (Pantone Greener Pastures, 256...  18999.0
# 4               4                 realme P4x 5G (Lake Green, 256 GB)  17499.0
# ...           ...                                                ...      ...
# 11971       11971                   OPPO A6x 5G (Olive Green, 64 GB)  12499.0
# 11972       11972                  OPPO A6x 5G (Olive Green, 128 GB)  13499.0
# 11973       11973  realme C63 5G Charger in the Box (Forest Green...  10999.0
# 11974       11974           vivo Y19s 5G (Titanium Silver, 128.0 GB)  14499.0
# 11975       11975                  realme C73 5G (Onyx Black, 64 GB)  11999.0
#
# ...

# %%
df.sort_values(['Densrank'])
# Out:
#      Unnamed: 0                                         Model Name  Price  \
# 365         365                                       OPPO K12X 5G    NaN
# 321         321                   vivo T1 44W (Starry Sky, 128 GB)    NaN
# 334         334                                         I Kall K25    NaN
# 528         528     I Kall K555 TOUCH AND TYPE Phone (Blue, 16 GB)    NaN
# 431         431                                         I Kall K25    NaN
# ..          ...                                                ...    ...
# 335         335                                       TRYTO T1 106  680.0
# 434         434  Vox V17 New - Keypad Mobile Phone with 1.8" di...  655.0
# 573         573  IAIR Basic Feature Dual Sim Mobile Phone with ...  610.0
# 491         491                                           Peace P6  599.0
# 529         529                                           Peace P2  598.0
#
#        Manufacture Percentage Discount   Ratings  Reviews  \
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0                                         Model Name    Price  \
# 0           0                vivo T4x 5G (Pronto Purple, 256 GB)  18499.0
# 1           1    MOTOROLA G96 5G (Pantone Ashleigh Blue, 256 GB)  18999.0
# 2           2                vivo T4x 5G (Pronto Purple, 128 GB)  16499.0
# 3           3  MOTOROLA G96 5G (Pantone Greener Pastures, 256...  18999.0
# 4           4                 realme P4x 5G (Lake Green, 256 GB)  17499.0
# 5           5  OPPO K13 5G with 7000mAh and 80W SUPERVOOC Cha...  19999.0
# 6           6                  vivo T4x 5G (Marine Blue, 128 GB)  16499.0
# 7           7                 realme P4 5G (Engine Blue, 128 GB)  17999.0
# 8           8  MOTOROLA G86 Power 5G (Pantone Cosmic Sky, 128...  16999.0
# 9           9  MOTOROLA G86 Power 5G (Pantone Golden Cypress,...  16999.0
#
#      Manufacture Percentage Discount   Ratings  Reviews  \
# 0  Made in india             11% off  151361.0   7146.0
# ...

# %%
df['Price'].value_counts()
# Out:
# Price
# 11999.0    2321
# 12499.0    1391
# 12999.0     954
# 13999.0     945
# 14999.0     942
#            ...
# 13580.0       1
# 1295.0        1
# 785.0         1
# 2149.0        1
# 8297.0        1
# Name: count, Length: 316, dtype: int64

# %%
df['Model Name'].nunique()
# Out:
# 659

# %%
df
# Out:
#        Unnamed: 0                                         Model Name    Price  \
# 0               0                vivo T4x 5G (Pronto Purple, 256 GB)  18499.0
# 1               1    MOTOROLA G96 5G (Pantone Ashleigh Blue, 256 GB)  18999.0
# 2               2                vivo T4x 5G (Pronto Purple, 128 GB)  16499.0
# 3               3  MOTOROLA G96 5G (Pantone Greener Pastures, 256...  18999.0
# 4               4                 realme P4x 5G (Lake Green, 256 GB)  17499.0
# ...           ...                                                ...      ...
# 11971       11971                   OPPO A6x 5G (Olive Green, 64 GB)  12499.0
# 11972       11972                  OPPO A6x 5G (Olive Green, 128 GB)  13499.0
# 11973       11973  realme C63 5G Charger in the Box (Forest Green...  10999.0
# 11974       11974           vivo Y19s 5G (Titanium Silver, 128.0 GB)  14499.0
# 11975       11975                  realme C73 5G (Onyx Black, 64 GB)  11999.0
#
# ...

# %%
df[(df['Price']>=15000)&(df['Price']<=20000)]
# Out:
#      Unnamed: 0                                         Model Name    Price  \
# 0             0                vivo T4x 5G (Pronto Purple, 256 GB)  18499.0
# 1             1    MOTOROLA G96 5G (Pantone Ashleigh Blue, 256 GB)  18999.0
# 2             2                vivo T4x 5G (Pronto Purple, 128 GB)  16499.0
# 3             3  MOTOROLA G96 5G (Pantone Greener Pastures, 256...  18999.0
# 4             4                 realme P4x 5G (Lake Green, 256 GB)  17499.0
# ..          ...                                                ...      ...
# 763         763       Samsung Galaxy F23 5G (Copper Blush, 128 GB)  17862.0
# 764         764                   POCO X3 Pro (Steel Blue, 128 GB)  18999.0
# 765         765                     vivo Z1Pro (Sonic Blue, 64 GB)  15990.0
# 766         766  Infinix Note 11s Free Fire Edition (Mithril Gr...  15999.0
# 767         767  Infinix Note 11s Free Fire Edition (Haze Green...  15999.0
#
# ...
